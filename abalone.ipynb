# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
trainDir = 'data/train.csv'
df = pd.read_csv(trainDir)
df.head()
# Out:
#    id Sex  Length  Diameter  Height  Whole weight  Whole weight.1  \
# 0   0   F   0.550     0.430   0.150        0.7715          0.3285
# 1   1   F   0.630     0.490   0.145        1.1300          0.4580
# 2   2   I   0.160     0.110   0.025        0.0210          0.0055
# 3   3   M   0.595     0.475   0.150        0.9145          0.3755
# 4   4   I   0.555     0.425   0.130        0.7820          0.3695
#
#    Whole weight.2  Shell weight  Rings
# 0          0.1465        0.2400     11
# 1          0.2765        0.3200     11
# 2          0.0030        0.0050      6
# 3          0.2055        0.2500     10
# 4          0.1600        0.1975      9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90615 entries, 0 to 90614
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              90615 non-null  int64
#  1   Sex             90615 non-null  object
#  2   Length          90615 non-null  float64
#  3   Diameter        90615 non-null  float64
#  4   Height          90615 non-null  float64
#  5   Whole weight    90615 non-null  float64
#  6   Whole weight.1  90615 non-null  float64
#  7   Whole weight.2  90615 non-null  float64
#  8   Shell weight    90615 non-null  float64
#  9   Rings           90615 non-null  int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 6.9+ MB

# %%
df.describe()
# Out:
#                  id        Length      Diameter        Height  Whole weight  \
# count  90615.000000  90615.000000  90615.000000  90615.000000  90615.000000
# mean   45307.000000      0.517098      0.401679      0.135464      0.789035
# std    26158.441658      0.118217      0.098026      0.038008      0.457671
# min        0.000000      0.075000      0.055000      0.000000      0.002000
# 25%    22653.500000      0.445000      0.345000      0.110000      0.419000
# 50%    45307.000000      0.545000      0.425000      0.140000      0.799500
# 75%    67960.500000      0.600000      0.470000      0.160000      1.067500
# max    90614.000000      0.815000      0.650000      1.130000      2.825500
#
#        Whole weight.1  Whole weight.2  Shell weight         Rings
# count    90615.000000    90615.000000  90615.000000  90615.000000
# mean         0.340778        0.169422      0.225898      9.696794
# std          0.204428        0.100909      0.130203      3.176221
# ...

# %%
df.isnull().sum()
# Out:
# id                0
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Whole weight.1    0
# Whole weight.2    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
plt.bar(df['Rings'].value_counts().index,
        df['Rings'].value_counts().values)
plt.xlabel("Number of Rings")
plt.ylabel("Frequency")
plt.title("Target Value Frequency plot")
plt.show()

# %%
df.drop('id', axis=1, inplace=True)

# %% [markdown]
# # Using Pycaret to fit various models to this data and getting results

# %%
# !pip install --pre pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.1/486.1 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 27.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.5/160.5 kB 13.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.0/258.0 kB 23.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 55.2 MB/s eta 0:00:00
# ...

# %%
import pycaret

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Whole weight.1',
#        'Whole weight.2', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
from pycaret.regression import *

s = setup(df, target='Rings',
          numeric_features = ['Length', 'Diameter', 'Height', 'Whole weight', 'Whole weight.1', 'Whole weight.2', 'Shell weight'],
          categorical_features = ['Sex'],
          max_encoding_ohe=20)
# Out:
# <style type="text/css">
# #T_56afe_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_56afe" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56afe_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_56afe_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56afe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_56afe_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_56afe_row0_col1" class="data row0 col1" >6230</td>
#     </tr>
#     <tr>
#       <th id="T_56afe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_56afe_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_56afe_row1_col1" class="data row1 col1" >Rings</td>
#     </tr>
#     <tr>
#       <th id="T_56afe_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# %%time
best = compare_models()
# Out:
# <style type="text/css">
# #T_5ad2b th {
#   text-align: left;
# }
# ...

# %% [markdown]
# # We can see LightGBM gives us the best performance, so we can try and fine-tune this model by changing model parameters

# %%
# !pip install lightgbm scikit-learn

# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split

def rmsle(y_true, y_pred):
  return np.sqrt(np.mean(np.square(np.log1p(y_true) - np.log1p(y_pred))))

# %%
dummies = pd.get_dummies(df['Sex']).astype(int)
df_dummies = pd.concat([df, dummies], axis=1)

df_dummies.head()
df_dummies.drop('Sex', axis=1, inplace=True)

# %%
X = df_dummies.drop('Rings', axis=1)
y = df_dummies['Rings']

# %%
y.shape
# Out:
# (90615,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y)

# %%
model = lgb.LGBMRegressor()
model.fit(X_train, y_train)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005227 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1330
# [LightGBM] [Info] Number of data points in the train set: 63430, number of used features: 10
# [LightGBM] [Info] Start training from score 9.696989
# LGBMRegressor()

# %%
y_pred = model.predict(X_test)

# %%
y_pred = [round(x) for x in y_pred]

# %%
rmsle(y_test, y_pred)
# Out:
# 0.1534112232534468

# %%
df_test = pd.read_csv('data/test.csv')

# %%
dummies = pd.get_dummies(df_test['Sex']).astype(int)
df_test_dummies = pd.concat([df_test, dummies], axis=1)

# %%
df_test_dummies.head()
# Out:
#       id Sex  Length  Diameter  Height  Whole weight  Whole weight.1  \
# 0  90615   M   0.645     0.475   0.155        1.2380          0.6185
# 1  90616   M   0.580     0.460   0.160        0.9830          0.4785
# 2  90617   M   0.560     0.420   0.140        0.8395          0.3525
# 3  90618   M   0.570     0.490   0.145        0.8740          0.3525
# 4  90619   I   0.415     0.325   0.110        0.3580          0.1575
#
#    Whole weight.2  Shell weight  F  I  M
# 0          0.3125        0.3005  0  0  1
# 1          0.2195        0.2750  0  0  1
# 2          0.1845        0.2405  0  0  1
# 3          0.1865        0.2350  0  0  1
# 4          0.0670        0.1050  0  1  0

# %%
df_test_dummies.drop('Sex', axis=1, inplace=True)

# %%
id = df_test_dummies['id']
df_test_dummies.drop('id', inplace=True, axis=1)

# %%
df_test_dummies.head()
# Out:
#    Length  Diameter  Height  Whole weight  Whole weight.1  Whole weight.2  \
# 0   0.645     0.475   0.155        1.2380          0.6185          0.3125
# 1   0.580     0.460   0.160        0.9830          0.4785          0.2195
# 2   0.560     0.420   0.140        0.8395          0.3525          0.1845
# 3   0.570     0.490   0.145        0.8740          0.3525          0.1865
# 4   0.415     0.325   0.110        0.3580          0.1575          0.0670
#
#    Shell weight  F  I  M
# 0        0.3005  0  0  1
# 1        0.2750  0  0  1
# 2        0.2405  0  0  1
# 3        0.2350  0  0  1
# 4        0.1050  0  1  0

# %%
preds = model.predict(df_test_dummies)

# %%
preds = [round(x) for x in preds]

# %%
sub_df = pd.concat([id, pd.Series(preds)], axis=1)

# %%
sub_df.head()
# Out:
#       id   0
# 0  90615  10
# 1  90616  10
# 2  90617  10
# 3  90618  10
# 4  90619   8

# %%
sub_df.to_csv('submission.csv', index=False)
